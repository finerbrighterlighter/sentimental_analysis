# %%
# Utilities
from tqdm.auto import tqdm
tqdm.pandas()
import numpy as np
import pandas as pd

# NLP
import spacy 
from spacy.lang.en.stop_words import STOP_WORDS

import nltk
from nltk import sent_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download("punkt")
nltk.download("vader_lexicon")

# Evaluation
from sklearn.metrics import accuracy_score,classification_report

PATH = "/content/drive/My Drive/sen_ana/"
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# /usr/local/lib/python3.6/dist-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
df = pd.read_csv(PATH+"candidate_hospitals_translated.csv")
df
# Out:
#                                                comment  ...                                                 en
# 0    เคยได้ไปลองใช้บริการคลีนิคนอกเวลาของรามาเมื่อต...  ...  Ever were going to try to use the service, the...
# 1    ผมเคยไปทำเลสิกที่นี้ ดีมากครับตอนนี้ผ่ามาจะ2ปี...  ...  I've been to Lasik the this good now. coming t...
# 2    รักษามาหลายปีแล้วตั้งแต่อายุ14 ตอนนี้จะจบปริญญ...  ...  Treatment for years since the age of 14 will n...
# 3    ที่ตึกพระเทพชั้น 2 สถานที่เครื่องมือดูทันสมัย ...  ...  Building the floor 2. place tools, modern look...
# 4    Its a public hospital so service is bad (nurse...  ...  Its a public hospital so service is bad (the n...
# ..                                                 ...  ...                                                ...
# 702  ค่ำวันที่ 26 ตุลาคม 2559 เหตุการณ์ในวันนั้นฉัน...  ...  Evening of October 26, 2559 event on that day,...
# 703  ทำเพื่ออะไรรีวิวนี้แต่เราไปรักษารพจุฬาก็ได้รับ...  ...  Do what for this review, but we to maintain th...
# 704  ทาง รพ. บริการคนไข้ดีมาก ใส่ใจผู้ป่วย เป็นกันเ...  ...  The hospital. Services, patient, very attentiv...
# 705                                            หมอเก่ง  ...                             The doctor brilliantly
# 706  เมื่อวันที่ 7 เมษายน 2559 ตัวผมเองรุ้สึกว่าไม่...  ...  On April 7, 2559, I myself feel that there is ...
#
# [707 rows x 4 columns]

# %%
# Stopword removal and Lemmanization

nlp = spacy.load("en_core_web_sm")

def stop(text):
  cleaned_token = []
  doc = nlp(text) 

  for word in doc:
    if word.lemma_ not in STOP_WORDS:
      cleaned_token.append(word.lemma_)
  return cleaned_token

# %%
# cleaned in sentences

sent_clean = pd.DataFrame(df.en.progress_apply(lambda x: stop(x)))
sent_clean = pd.DataFrame(sent_clean.en.progress_apply(lambda x:' '.join(x)))
sent_clean["score"] = df.score
sent_clean["hospital"] = df.hospital
# Out:
# HBox(children=(FloatProgress(value=0.0, max=707.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=707.0), HTML(value='')))

# %%
# score 3 ignored, score 1,2 as bad, score 4,5 as good

sent_clean = sent_clean.loc[sent_clean.score != 3]
sent_clean["sen"] = 0
sent_clean.loc[sent_clean.score.isin([4,5]),["sen"]] = 1
sent_clean
# Out:
#                                                     en  ...  sen
# 0    try use service , clinic , Rama beginning trea...  ...    1
# 1    -PRON- Lasik good . come 2 year , price good m...  ...    1
# 2    treatment year age 14 finish -PRON- degree , s...  ...    1
# 4    -PRON- public hospital service bad ( nurse com...  ...    1
# 5    -PRON- friend disease pulmonary leak doctor ca...  ...    1
# ..                                                 ...  ...  ...
# 701  large hospital , lot people , doctor nurse , g...  ...    1
# 702  evening October 26 , 2559 event day , -PRON- r...  ...    1
# 703  review , -PRON- maintain CHULA treat , . today...  ...    1
# 704  hospital . service , patient , attentive , pat...  ...    1
# 706  April 7 , 2559 , -PRON- -PRON- feel stamina to...  ...    1
#
# [641 rows x 4 columns]

# %%
sent_clean.to_csv(PATH+"sentence_clean.csv",index=False)

# %%
def comment_polarity(df):
  sa = SentimentIntensityAnalyzer()
  polar = []
  for i in df.index:
    # sentiment per sentence of each comment
    for sentence in sent_tokenize(df.loc[i, 'en']):
      sentiment_distribution = sa.polarity_scores(sentence)
      score = sentiment_distribution.get("compound")
      # total of the comment
      score += score
    if score >=0:
      polar.append(1)
    else:
      polar.append(0)
  return polar

# %%
polar = comment_polarity(sent_clean)

# %%
accuracy_score(sent_clean.sen,polar)
# Out:
# 0.797191887675507

# %%
print(classification_report(sent_clean.sen,polar))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.49      0.39      0.43       127
#            1       0.86      0.90      0.88       514
#
#     accuracy                           0.80       641
#    macro avg       0.67      0.64      0.65       641
# weighted avg       0.78      0.80      0.79       641
