# %% [markdown]
# # Library

# %% [markdown]
# There is a daily limit for google translate. <br>
# I will apply Yandex Translate instead.

# %%
# !pip install yandex-translater
# Out:
# Collecting yandex-translater
#   Downloading https://files.pythonhosted.org/packages/8c/fa/c65a83cd5a0e9860f8dae2c4dd27f76bc100241508a2e29127f6c4f63b9f/yandex_translater-6.0-py2.py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from yandex-translater) (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->yandex-translater) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->yandex-translater) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->yandex-translater) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->yandex-translater) (1.24.3)
# Installing collected packages: yandex-translater
# Successfully installed yandex-translater-6.0

# %%
# Web scraping
import requests
from bs4 import BeautifulSoup
from time import time,sleep
from random import randint

# Utilities
from tqdm.auto import tqdm
import numpy as np
import pandas as pd

# Download
from google.colab import files

PATH = "/content/drive/My Drive/sen_ana/"

# %% [markdown]
# # Scraping

# %%
def honestdoc_comment(url):
    """
    This function is to scrap data from a webboard (https://www.honestdocs.com).

    INPUT
    url : String
      URL of the target website
    
    OUTPUT
    comment : List
      List of comments
    score : List
      List of rating score
    """
    #create connection
    data = requests.get(url)
    print("requests code : {}".format(data.status_code)) 
    print("note\n2xx: success\n4xx, 5xx: error")
    
    #scrape comment and score
    start_time = time() #start scraping data from page1
    r = requests.get(url, params=dict(query="web scraping",page=1)) 
    soup = BeautifulSoup(r.text,"html.parser")
    n = len(soup.find_all("div",{"class":"comments__content"})) #find n of items in the page
    
    #extract each item
    comment = [soup.find_all("div",
                             {"class":"comments__content"})[i].get_text().strip() for i in range(0,n)]
    score = [soup.find_all("span",
                           {"class":"stars star-rating"})[i].attrs["data-score"] for i in range(0,n)]
    elapsed_time = time() - start_time #finish scraping data from page1
    print("Time used for scraping data from page - 1 : {} s".format(elapsed_time))
    sleep(randint(1,3)) #mimic human behavior
           
    p = 2 #start scraping data from page2
    while n > 0: #until the number of items in a page = 0
        start_time = time() 
        r = requests.get(url, params=dict(query="web scraping",page=p))
        soup = BeautifulSoup(r.text,"html.parser")
        n = len(soup.find_all("div",{"class":"comments__content"}))
        [comment.append(soup.find_all("div",
                                      {"class":"comments__content"})[i].get_text().strip()) for i in range(0,n)]
        [score.append(soup.find_all("span",
                                    {"class":"stars star-rating"})[i].attrs["data-score"]) for i in range(0,n)]
        elapsed_time = time() - start_time
        print("Time used for scraping data from page - {} : {} s".format(p, elapsed_time))
        p +=1
        sleep(randint(1,3))
    
    #backup data 
    pd.DataFrame({"comment": comment, 
                  "score": score,
                  "hospital": str(url[url.rfind("/")+1:])}).to_csv(PATH+"comment_"+str(url[url.rfind("/")+1:]) + ".csv", index=False)
    
    return comment, score

# %%
#scrape
comment, score = honestdoc_comment(r"https://www.honestdocs.co/hospitals/ramathibodi-hospital")

# restore data
rama = pd.read_csv(PATH+"comment_ramathibodi-hospital.csv")
rama.head()
# Out:
# requests code : 200
# note
# 2xx: success
# 4xx, 5xx: error
# Time used for scraping data from page - 1 : 1.5920238494873047 s
# Time used for scraping data from page - 2 : 1.6432509422302246 s
# Time used for scraping data from page - 3 : 1.573096752166748 s
# Time used for scraping data from page - 4 : 1.5943946838378906 s
# Time used for scraping data from page - 5 : 1.5959582328796387 s
# Time used for scraping data from page - 6 : 1.5650711059570312 s
# Time used for scraping data from page - 7 : 1.6089930534362793 s
# Time used for scraping data from page - 8 : 1.5843214988708496 s
# Time used for scraping data from page - 9 : 1.605072259902954 s
# Time used for scraping data from page - 10 : 1.6643476486206055 s
# Time used for scraping data from page - 11 : 1.56858229637146 s
# Time used for scraping data from page - 12 : 1.5768179893493652 s
# Time used for scraping data from page - 13 : 1.601515769958496 s
# Time used for scraping data from page - 14 : 1.5573623180389404 s
# Time used for scraping data from page - 15 : 1.6030724048614502 s
# Time used for scraping data from page - 16 : 1.5657975673675537 s
# Time used for scraping data from page - 17 : 1.648550271987915 s
# Time used for scraping data from page - 18 : 1.2996621131896973 s
# Time used for scraping data from page - 19 : 1.623042345046997 s
# Time used for scraping data from page - 20 : 1.650742769241333 s
# Time used for scraping data from page - 21 : 1.5770063400268555 s
# Time used for scraping data from page - 22 : 1.6115102767944336 s
# Time used for scraping data from page - 23 : 1.576941728591919 s
# Time used for scraping data from page - 24 : 1.5688560009002686 s
# Time used for scraping data from page - 25 : 1.6290526390075684 s
# Time used for scraping data from page - 26 : 1.6414315700531006 s
# Time used for scraping data from page - 27 : 1.6242022514343262 s
# Time used for scraping data from page - 28 : 1.583198070526123 s
# Time used for scraping data from page - 29 : 1.565816879272461 s
# Time used for scraping data from page - 30 : 1.5595204830169678 s
# Time used for scraping data from page - 31 : 1.5832340717315674 s
# Time used for scraping data from page - 32 : 1.5766785144805908 s
# Time used for scraping data from page - 33 : 1.5799665451049805 s
# Time used for scraping data from page - 34 : 1.6144981384277344 s
# Time used for scraping data from page - 35 : 1.6082494258880615 s
# Time used for scraping data from page - 36 : 1.571453332901001 s
# Time used for scraping data from page - 37 : 1.565751314163208 s
# Time used for scraping data from page - 38 : 1.621838092803955 s
# Time used for scraping data from page - 39 : 1.5651907920837402 s
# Time used for scraping data from page - 40 : 1.6002638339996338 s
# Time used for scraping data from page - 41 : 1.590984582901001 s
# Time used for scraping data from page - 42 : 1.6963863372802734 s
# Time used for scraping data from page - 43 : 1.5648109912872314 s
# Time used for scraping data from page - 44 : 1.5949981212615967 s
# Time used for scraping data from page - 45 : 1.5955448150634766 s
# Time used for scraping data from page - 46 : 1.5954315662384033 s
# Time used for scraping data from page - 47 : 1.2885770797729492 s
# Time used for scraping data from page - 48 : 1.6260175704956055 s
# Time used for scraping data from page - 49 : 1.553177833557129 s
# Time used for scraping data from page - 50 : 1.6290943622589111 s
# Time used for scraping data from page - 51 : 1.567265272140503 s
# Time used for scraping data from page - 52 : 1.5742197036743164 s
# Time used for scraping data from page - 53 : 1.6344847679138184 s
# Time used for scraping data from page - 54 : 1.5899205207824707 s
# Time used for scraping data from page - 55 : 1.5848040580749512 s
# Time used for scraping data from page - 56 : 1.6421949863433838 s
# Time used for scraping data from page - 57 : 1.5882411003112793 s
# Time used for scraping data from page - 58 : 1.6146948337554932 s
# Time used for scraping data from page - 59 : 1.5817327499389648 s
# Time used for scraping data from page - 60 : 1.5930066108703613 s
# Time used for scraping data from page - 61 : 1.569040060043335 s
# Time used for scraping data from page - 62 : 1.613246202468872 s
# Time used for scraping data from page - 63 : 1.57871675491333 s
# Time used for scraping data from page - 64 : 1.6513845920562744 s
# Time used for scraping data from page - 65 : 1.589524507522583 s
# Time used for scraping data from page - 66 : 1.581350564956665 s
# Time used for scraping data from page - 67 : 1.3417513370513916 s
# Time used for scraping data from page - 68 : 1.6072399616241455 s
# Time used for scraping data from page - 69 : 1.5765790939331055 s
# Time used for scraping data from page - 70 : 1.5673847198486328 s
# Time used for scraping data from page - 71 : 1.6409239768981934 s
# Time used for scraping data from page - 72 : 1.577688455581665 s
# Time used for scraping data from page - 73 : 1.61092209815979 s
# Time used for scraping data from page - 74 : 1.5972144603729248 s
# Time used for scraping data from page - 75 : 1.60268235206604 s
# Time used for scraping data from page - 76 : 1.2528653144836426 s
#                                              comment  ...              hospital
# 0  เคยได้ไปลองใช้บริการคลีนิคนอกเวลาของรามาเมื่อต...  ...  ramathibodi-hospital
# 1  ผมเคยไปทำเลสิกที่นี้ ดีมากครับตอนนี้ผ่ามาจะ2ปี...  ...  ramathibodi-hospital
# 2  รักษามาหลายปีแล้วตั้งแต่อายุ14 ตอนนี้จะจบปริญญ...  ...  ramathibodi-hospital
# 3  ที่ตึกพระเทพชั้น 2 สถานที่เครื่องมือดูทันสมัย ...  ...  ramathibodi-hospital
# 4  Its a public hospital so service is bad (nurse...  ...  ramathibodi-hospital
#
# [5 rows x 3 columns]

# %%
#scrape
comment, score = honestdoc_comment(r"https://www.honestdocs.co/hospitals/siriraj-hospital")

# restore data
siriraj = pd.read_csv(PATH+"comment_siriraj-hospital.csv")
siriraj.head()
# Out:
# requests code : 200
# note
# 2xx: success
# 4xx, 5xx: error
# Time used for scraping data from page - 1 : 1.7664403915405273 s
# Time used for scraping data from page - 2 : 1.6024212837219238 s
# Time used for scraping data from page - 3 : 1.7260518074035645 s
# Time used for scraping data from page - 4 : 1.6759154796600342 s
# Time used for scraping data from page - 5 : 1.5778965950012207 s
# Time used for scraping data from page - 6 : 1.6101596355438232 s
# Time used for scraping data from page - 7 : 1.5768942832946777 s
# Time used for scraping data from page - 8 : 1.595670223236084 s
# Time used for scraping data from page - 9 : 1.6447985172271729 s
# Time used for scraping data from page - 10 : 1.7298524379730225 s
# Time used for scraping data from page - 11 : 1.5760283470153809 s
# Time used for scraping data from page - 12 : 1.5674002170562744 s
# Time used for scraping data from page - 13 : 1.576171875 s
# Time used for scraping data from page - 14 : 1.595900535583496 s
# Time used for scraping data from page - 15 : 1.746518611907959 s
# Time used for scraping data from page - 16 : 1.5742528438568115 s
# Time used for scraping data from page - 17 : 1.5761878490447998 s
# Time used for scraping data from page - 18 : 1.5749189853668213 s
# Time used for scraping data from page - 19 : 1.6787171363830566 s
# Time used for scraping data from page - 20 : 1.5885698795318604 s
# Time used for scraping data from page - 21 : 1.5663905143737793 s
# Time used for scraping data from page - 22 : 1.5825045108795166 s
# Time used for scraping data from page - 23 : 1.6213252544403076 s
# Time used for scraping data from page - 24 : 1.5846726894378662 s
# Time used for scraping data from page - 25 : 1.600236415863037 s
# Time used for scraping data from page - 26 : 1.5975956916809082 s
# Time used for scraping data from page - 27 : 1.6059210300445557 s
# Time used for scraping data from page - 28 : 1.5812172889709473 s
# Time used for scraping data from page - 29 : 1.591243028640747 s
# Time used for scraping data from page - 30 : 1.571444034576416 s
# Time used for scraping data from page - 31 : 1.7020699977874756 s
# Time used for scraping data from page - 32 : 1.5647361278533936 s
# Time used for scraping data from page - 33 : 1.6334922313690186 s
# Time used for scraping data from page - 34 : 1.6536786556243896 s
# Time used for scraping data from page - 35 : 1.631420373916626 s
# Time used for scraping data from page - 36 : 1.5685291290283203 s
# Time used for scraping data from page - 37 : 1.572350025177002 s
# Time used for scraping data from page - 38 : 1.5662100315093994 s
# Time used for scraping data from page - 39 : 1.599510669708252 s
# Time used for scraping data from page - 40 : 1.5949876308441162 s
# Time used for scraping data from page - 41 : 1.614060640335083 s
# Time used for scraping data from page - 42 : 1.6678030490875244 s
# Time used for scraping data from page - 43 : 1.5652666091918945 s
# Time used for scraping data from page - 44 : 1.578049898147583 s
# Time used for scraping data from page - 45 : 1.522111415863037 s
#                                              comment  score          hospital
# 0  พยาบาลบริการดีคุณหมอสุภาพโรงพยาบาลรักษาความสะอ...      5  siriraj-hospital
# 1  ใช้บริการปรึกษาเรื่องแผลคีลอยด์ที่บริเวรต้นแขน...      5  siriraj-hospital
# 2  เป็นโรงพยาบาลที่ดีมากๆคะเคยรักษาเนื้องอกที่มดล...      5  siriraj-hospital
# 3  รพ.ศิริราช คุณหมอและพยาบาลน่ารักมากค่ะ ให้คำแน...      5  siriraj-hospital
# 4  พาคุณย่าไปรักษาโรคมะเร็ง บริการดี รวดเร็วเป็นก...      5  siriraj-hospital

# %%
#scrape
comment, score = honestdoc_comment(r"https://www.honestdocs.co/hospitals/king-chulalongkorn-memorial-hospital")

# restore data
chula = pd.read_csv(PATH+"comment_king-chulalongkorn-memorial-hospital.csv")
chula.head()
# Out:
# requests code : 200
# note
# 2xx: success
# 4xx, 5xx: error
# Time used for scraping data from page - 1 : 1.5743703842163086 s
# Time used for scraping data from page - 2 : 1.6330108642578125 s
# Time used for scraping data from page - 3 : 1.6072766780853271 s
# Time used for scraping data from page - 4 : 1.5983190536499023 s
# Time used for scraping data from page - 5 : 1.5835871696472168 s
# Time used for scraping data from page - 6 : 1.5709173679351807 s
# Time used for scraping data from page - 7 : 1.618823766708374 s
# Time used for scraping data from page - 8 : 1.7265453338623047 s
# Time used for scraping data from page - 9 : 1.5819408893585205 s
# Time used for scraping data from page - 10 : 1.586329460144043 s
# Time used for scraping data from page - 11 : 1.5740118026733398 s
# Time used for scraping data from page - 12 : 1.5558607578277588 s
# Time used for scraping data from page - 13 : 1.577207088470459 s
# Time used for scraping data from page - 14 : 1.5785541534423828 s
# Time used for scraping data from page - 15 : 1.6955304145812988 s
# Time used for scraping data from page - 16 : 1.6301207542419434 s
# Time used for scraping data from page - 17 : 1.6549384593963623 s
# Time used for scraping data from page - 18 : 1.5820591449737549 s
# Time used for scraping data from page - 19 : 1.5513901710510254 s
# Time used for scraping data from page - 20 : 1.5674302577972412 s
# Time used for scraping data from page - 21 : 1.5693504810333252 s
# Time used for scraping data from page - 22 : 1.5561940670013428 s
# Time used for scraping data from page - 23 : 1.5894854068756104 s
# Time used for scraping data from page - 24 : 1.6442210674285889 s
# Time used for scraping data from page - 25 : 1.5706095695495605 s
# Time used for scraping data from page - 26 : 1.6028478145599365 s
# Time used for scraping data from page - 27 : 1.5651614665985107 s
# Time used for scraping data from page - 28 : 1.5707025527954102 s
# Time used for scraping data from page - 29 : 1.5906782150268555 s
# Time used for scraping data from page - 30 : 1.6040565967559814 s
# Time used for scraping data from page - 31 : 1.7679297924041748 s
# Time used for scraping data from page - 32 : 1.6042566299438477 s
# Time used for scraping data from page - 33 : 1.610351800918579 s
# Time used for scraping data from page - 34 : 1.5777544975280762 s
# Time used for scraping data from page - 35 : 1.5660443305969238 s
# Time used for scraping data from page - 36 : 1.57722806930542 s
# Time used for scraping data from page - 37 : 1.576418399810791 s
# Time used for scraping data from page - 38 : 1.5720102787017822 s
# Time used for scraping data from page - 39 : 1.6162364482879639 s
# Time used for scraping data from page - 40 : 1.585247278213501 s
# Time used for scraping data from page - 41 : 1.5965299606323242 s
# Time used for scraping data from page - 42 : 1.5948808193206787 s
# Time used for scraping data from page - 43 : 1.613332748413086 s
# Time used for scraping data from page - 44 : 1.6161086559295654 s
# Time used for scraping data from page - 45 : 1.5777091979980469 s
# Time used for scraping data from page - 46 : 1.5683143138885498 s
# Time used for scraping data from page - 47 : 1.5715837478637695 s
# Time used for scraping data from page - 48 : 1.6139376163482666 s
# Time used for scraping data from page - 49 : 1.5704548358917236 s
# Time used for scraping data from page - 50 : 1.580564022064209 s
# Time used for scraping data from page - 51 : 1.5777325630187988 s
# Time used for scraping data from page - 52 : 1.5833208560943604 s
# Time used for scraping data from page - 53 : 1.573824167251587 s
# Time used for scraping data from page - 54 : 1.5643889904022217 s
# Time used for scraping data from page - 55 : 1.6657934188842773 s
# Time used for scraping data from page - 56 : 1.5707812309265137 s
# Time used for scraping data from page - 57 : 1.5746054649353027 s
# Time used for scraping data from page - 58 : 1.5679042339324951 s
# Time used for scraping data from page - 59 : 1.5678820610046387 s
# Time used for scraping data from page - 60 : 1.5741488933563232 s
# Time used for scraping data from page - 61 : 1.5805745124816895 s
# Time used for scraping data from page - 62 : 1.6401159763336182 s
# Time used for scraping data from page - 63 : 1.6131811141967773 s
# Time used for scraping data from page - 64 : 1.5913491249084473 s
# Time used for scraping data from page - 65 : 1.6870200634002686 s
# Time used for scraping data from page - 66 : 1.6150028705596924 s
# Time used for scraping data from page - 67 : 1.5678958892822266 s
# Time used for scraping data from page - 68 : 1.573807716369629 s
# Time used for scraping data from page - 69 : 1.6112444400787354 s
# Time used for scraping data from page - 70 : 1.6053364276885986 s
# Time used for scraping data from page - 71 : 1.5542175769805908 s
# Time used for scraping data from page - 72 : 1.5954928398132324 s
# Time used for scraping data from page - 73 : 1.5570182800292969 s
# Time used for scraping data from page - 74 : 1.6066737174987793 s
# Time used for scraping data from page - 75 : 1.5652759075164795 s
# Time used for scraping data from page - 76 : 1.6230318546295166 s
# Time used for scraping data from page - 77 : 1.6710097789764404 s
# Time used for scraping data from page - 78 : 1.6023414134979248 s
# Time used for scraping data from page - 79 : 1.5722882747650146 s
# Time used for scraping data from page - 80 : 1.576453447341919 s
# Time used for scraping data from page - 81 : 1.611243724822998 s
# Time used for scraping data from page - 82 : 1.579883098602295 s
# Time used for scraping data from page - 83 : 1.6746320724487305 s
# Time used for scraping data from page - 84 : 1.5746421813964844 s
# Time used for scraping data from page - 85 : 1.661942958831787 s
# Time used for scraping data from page - 86 : 1.571427822113037 s
# Time used for scraping data from page - 87 : 1.585745096206665 s
# Time used for scraping data from page - 88 : 1.5944945812225342 s
# Time used for scraping data from page - 89 : 1.5961766242980957 s
# Time used for scraping data from page - 90 : 1.5860490798950195 s
# Time used for scraping data from page - 91 : 1.6150527000427246 s
# Time used for scraping data from page - 92 : 1.5714797973632812 s
# Time used for scraping data from page - 93 : 1.6074554920196533 s
# Time used for scraping data from page - 94 : 1.5606961250305176 s
# Time used for scraping data from page - 95 : 1.6119942665100098 s
# Time used for scraping data from page - 96 : 1.5715019702911377 s
# Time used for scraping data from page - 97 : 1.6100022792816162 s
# Time used for scraping data from page - 98 : 1.5919837951660156 s
# Time used for scraping data from page - 99 : 1.6644377708435059 s
# Time used for scraping data from page - 100 : 1.5840036869049072 s
# Time used for scraping data from page - 101 : 1.6215415000915527 s
# Time used for scraping data from page - 102 : 1.5891234874725342 s
# Time used for scraping data from page - 103 : 1.6028614044189453 s
# Time used for scraping data from page - 104 : 1.572058916091919 s
# Time used for scraping data from page - 105 : 1.5674149990081787 s
# Time used for scraping data from page - 106 : 1.5739431381225586 s
# Time used for scraping data from page - 107 : 1.584134578704834 s
# Time used for scraping data from page - 108 : 1.6626062393188477 s
# Time used for scraping data from page - 109 : 1.5534031391143799 s
# Time used for scraping data from page - 110 : 1.634817361831665 s
# Time used for scraping data from page - 111 : 1.625525951385498 s
# Time used for scraping data from page - 112 : 1.5885910987854004 s
# Time used for scraping data from page - 113 : 1.5767323970794678 s
# Time used for scraping data from page - 114 : 1.595154047012329 s
# Time used for scraping data from page - 115 : 1.581873893737793 s
# Time used for scraping data from page - 116 : 1.5821552276611328 s
# Time used for scraping data from page - 117 : 1.6408803462982178 s
# Time used for scraping data from page - 118 : 1.596573829650879 s
# Time used for scraping data from page - 119 : 1.5423085689544678 s
# Time used for scraping data from page - 120 : 1.6000897884368896 s
#                                              comment  ...                              hospital
# 0  เรื่อง ของเรื่องมีอยู่ว่า ไม่มีไข้ แต่โดนกักตั...  ...  king-chulalongkorn-memorial-hospital
# 1  บริการค่อนข้างดีค่ะ คุณหมอพยาบาลใจดีเป็นกันเอง...  ...  king-chulalongkorn-memorial-hospital
# 2  ไปรับการตรวจเรื่องเม็ดเลือดในปัสสาวะค่ะ ต้องจอ...  ...  king-chulalongkorn-memorial-hospital
# 3  บริการค่อยข้างดีค่ะ แต่รอคิวนานนิดหน่อย แต่วิน...  ...  king-chulalongkorn-memorial-hospital
# 4  ได้มีอาการอาหารเป็นพิษและเข้าทำการรักษาที่โรงพ...  ...  king-chulalongkorn-memorial-hospital
#
# [5 rows x 3 columns]

# %% [markdown]
# I will use all three files in one dataframe, since it is more convenient for me. Separate files will be submitted for evaluation.

# %%
candi_hosp = pd.concat([rama,siriraj,chula], axis=0, ignore_index=True)
candi_hosp.to_csv(PATH+"candidate_hospitals.csv", index=False)
candi_hosp
# Out:
#                                                comment  ...                              hospital
# 0    เคยได้ไปลองใช้บริการคลีนิคนอกเวลาของรามาเมื่อต...  ...                  ramathibodi-hospital
# 1    ผมเคยไปทำเลสิกที่นี้ ดีมากครับตอนนี้ผ่ามาจะ2ปี...  ...                  ramathibodi-hospital
# 2    รักษามาหลายปีแล้วตั้งแต่อายุ14 ตอนนี้จะจบปริญญ...  ...                  ramathibodi-hospital
# 3    ที่ตึกพระเทพชั้น 2 สถานที่เครื่องมือดูทันสมัย ...  ...                  ramathibodi-hospital
# 4    Its a public hospital so service is bad (nurse...  ...                  ramathibodi-hospital
# ..                                                 ...  ...                                   ...
# 706  ค่ำวันที่ 26 ตุลาคม 2559 เหตุการณ์ในวันนั้นฉัน...  ...  king-chulalongkorn-memorial-hospital
# 707  ทำเพื่ออะไรรีวิวนี้แต่เราไปรักษารพจุฬาก็ได้รับ...  ...  king-chulalongkorn-memorial-hospital
# 708  ทาง รพ. บริการคนไข้ดีมาก ใส่ใจผู้ป่วย เป็นกันเ...  ...  king-chulalongkorn-memorial-hospital
# 709                                            หมอเก่ง  ...  king-chulalongkorn-memorial-hospital
# 710  เมื่อวันที่ 7 เมษายน 2559 ตัวผมเองรุ้สึกว่าไม่...  ...  king-chulalongkorn-memorial-hospital
#
# [711 rows x 3 columns]

# %% [markdown]
# # Duplicate comments

# %%
pd.concat(g for _, g in candi_hosp.groupby(["comment", "hospital"]) if len(g) > 1)

# apparently same comment, different scores
# row indexs are quite close, they will be considered duplicates
# will only keep the first row
# Out:
#                                                comment  ...                              hospital
# 364  ตรวจดีมากๆค่ะคุณหมอละเอียด พยาบาลก็ดีดูแลคนไข้...  ...  king-chulalongkorn-memorial-hospital
# 367  ตรวจดีมากๆค่ะคุณหมอละเอียด พยาบาลก็ดีดูแลคนไข้...  ...  king-chulalongkorn-memorial-hospital
# 13   เป็นโรงพยาบาลที่ทั้งครอบครัวและญาติใช้บริการ ร...  ...                  ramathibodi-hospital
# 14   เป็นโรงพยาบาลที่ทั้งครอบครัวและญาติใช้บริการ ร...  ...                  ramathibodi-hospital
# 16   เป็นโรงพยาบาลที่ทั้งครอบครัวและญาติใช้บริการ ร...  ...                  ramathibodi-hospital
# 251  โรงพยาบาลมีคลินิคผู้ป่วยนอก มีคนมาใช้บริการเยอ...  ...                      siriraj-hospital
# 254  โรงพยาบาลมีคลินิคผู้ป่วยนอก มีคนมาใช้บริการเยอ...  ...                      siriraj-hospital
#
# [7 rows x 3 columns]

# %%
candi_hosp.drop_duplicates(subset=["comment", "hospital"],keep='first',inplace=True)
candi_hosp.reset_index(inplace=True,drop=True)
candi_hosp

# 4 rows removed (1 for chula, 2 for rama, 1 for siriraj )
# Out:
#                                                comment  ...                              hospital
# 0    เคยได้ไปลองใช้บริการคลีนิคนอกเวลาของรามาเมื่อต...  ...                  ramathibodi-hospital
# 1    ผมเคยไปทำเลสิกที่นี้ ดีมากครับตอนนี้ผ่ามาจะ2ปี...  ...                  ramathibodi-hospital
# 2    รักษามาหลายปีแล้วตั้งแต่อายุ14 ตอนนี้จะจบปริญญ...  ...                  ramathibodi-hospital
# 3    ที่ตึกพระเทพชั้น 2 สถานที่เครื่องมือดูทันสมัย ...  ...                  ramathibodi-hospital
# 4    Its a public hospital so service is bad (nurse...  ...                  ramathibodi-hospital
# ..                                                 ...  ...                                   ...
# 702  ค่ำวันที่ 26 ตุลาคม 2559 เหตุการณ์ในวันนั้นฉัน...  ...  king-chulalongkorn-memorial-hospital
# 703  ทำเพื่ออะไรรีวิวนี้แต่เราไปรักษารพจุฬาก็ได้รับ...  ...  king-chulalongkorn-memorial-hospital
# 704  ทาง รพ. บริการคนไข้ดีมาก ใส่ใจผู้ป่วย เป็นกันเ...  ...  king-chulalongkorn-memorial-hospital
# 705                                            หมอเก่ง  ...  king-chulalongkorn-memorial-hospital
# 706  เมื่อวันที่ 7 เมษายน 2559 ตัวผมเองรุ้สึกว่าไม่...  ...  king-chulalongkorn-memorial-hospital
#
# [707 rows x 3 columns]

# %% [markdown]
# # Comment Translation

# %%
# Thai to English translation
from yandex.Translater import Translater

tr = Translater()
tr.set_key("trnsl.1.1.20200512T034022Z.ed5d7ccf14643c28.17c7515c3869f75fb38e02d7daadd421b8a7eb6b")
tr.set_from_lang("th")
tr.set_to_lang("en")

# %%
def th2en(comment):
  tr.set_text(comment)
  return tr.translate()

# %%
#translate
tqdm.pandas()
candi_hosp["en"] = candi_hosp.progress_apply(lambda x: th2en(x["comment"]), axis=1)

#print
candi_hosp.head()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=707.0), HTML(value='')))
#                                              comment  ...                                                 en
# 0  เคยได้ไปลองใช้บริการคลีนิคนอกเวลาของรามาเมื่อต...  ...  Ever were going to try to use the service, the...
# 1  ผมเคยไปทำเลสิกที่นี้ ดีมากครับตอนนี้ผ่ามาจะ2ปี...  ...  I've been to Lasik the this good now. coming t...
# 2  รักษามาหลายปีแล้วตั้งแต่อายุ14 ตอนนี้จะจบปริญญ...  ...  Treatment for years since the age of 14 will n...
# 3  ที่ตึกพระเทพชั้น 2 สถานที่เครื่องมือดูทันสมัย ...  ...  Building the floor 2. place tools, modern look...
# 4  Its a public hospital so service is bad (nurse...  ...  Its a public hospital so service is bad (the n...
#
# [5 rows x 4 columns]

# %%
candi_hosp.to_csv(PATH+"candidate_hospitals_translated.csv")
